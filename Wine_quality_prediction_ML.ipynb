# %% [markdown]
# # **Name : Simran Gonsalves**

# %% [markdown]
# # **Prediction of White Wine Quality Using Machine Learning Concepts**

# %% [markdown]
# ![wp8877714-white-wine-wallpapers.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The White wine dataset (related to the wine making process) used for this project was obtained from kaggle. This dataset contains 4,898 white wines and has 12 fundamental features which are responsible for affecting the quality of the wine. By the use of different Machine learning models, the predicction of the quality of white wine is done.
#
#
# ---

# %% [markdown]
# As the first step, all the required libraries and the dataset is imported.

# %% [markdown]
# # **DATA LOADING**

# %%
import pandas as pd    # data analysis
import numpy as np     # used for working with arrays
import seaborn as sns  # data visualization
import matplotlib.pyplot as plt   # data visualization

# %%
df = pd.read_csv('Wine.csv')   # loading the  data
df.head()    # returns the first five observations of the dataset
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.0              0.27         0.36  ...       0.45      8.8        6
# 1            6.3              0.30         0.34  ...       0.49      9.5        6
# 2            8.1              0.28         0.40  ...       0.44     10.1        6
# 3            7.2              0.23         0.32  ...       0.40      9.9        6
# 4            7.2              0.23         0.32  ...       0.40      9.9        6
#
# [5 rows x 12 columns]

# %%
df.tail()  # returns the last five observations of the dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 4893            6.2              0.21         0.29  ...       0.50     11.2        6
# 4894            6.6              0.32         0.36  ...       0.46      9.6        5
# 4895            6.5              0.24         0.19  ...       0.46      9.4        6
# 4896            5.5              0.29         0.30  ...       0.38     12.8        7
# 4897            6.0              0.21         0.38  ...       0.32     11.8        6
#
# [5 rows x 12 columns]

# %% [markdown]
# # **DATA PRE-PROCESSING**

# %%
#Shape (rows,columns) of the data
df.shape
# Out:
# (4898, 12)

# %% [markdown]
# This dataset comprises of 4898 observations and 12 features.
# Here 'quality' feature is dependent variable and others are independent variables.
#
#
# ---

# %%
df.columns.values  # gives the label for each column
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
# getting info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# This dataset has only float and integers value.
#
#
# ---

# %% [markdown]
# ### **Checking for any Null values**

# %%
df.isna().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %% [markdown]
# From the above output we can see that there are no missing values in this dataset.
#
#
# ---

# %%
# Statistical description of the dataset
df.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    4898.000000       4898.000000  ...  4898.000000  4898.000000
# mean        6.854788          0.278241  ...    10.514267     5.877909
# std         0.843868          0.100795  ...     1.230621     0.885639
# min         3.800000          0.080000  ...     8.000000     3.000000
# 25%         6.300000          0.210000  ...     9.500000     5.000000
# 50%         6.800000          0.260000  ...    10.400000     6.000000
# 75%         7.300000          0.320000  ...    11.400000     6.000000
# max        14.200000          1.100000  ...    14.200000     9.000000
#
# [8 rows x 12 columns]

# %% [markdown]
# Here some useful statistical information is obtained, like,
#
# Mean (Average): adding up all the sample values for a given feature, then dividing it by the number of samples.
#
# Median: The middle number in the list of ascending order.
#
# Mode: The value that occurs the most in a list of samples.
#
# Range: The difference between the highest value and the lowest values in a list.
#
# Standard Deviation: used to measure the dispersion of values in a set.
#
#
# ---

# %% [markdown]
# # **DATA VISUALIZATION AND ANALYSIS OF FEATURES**
#
#
# ---

# %% [markdown]
# ## **1. QUALITY**
#
#
# ---

# %%
df.quality.unique()  # to find the unique values for quality
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %% [markdown]
# "quality" score scale ranges from 1 to 10, where 1 being poor and 10 being the best.
#
# 1,2 & 10 Quality ratings are not given by any obseravtion.Only scores obtained are between 3 to 9.
#
#
# ---

# %%
df.quality.value_counts()   # to find the frequency of unique values
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# This tells the count of each quality score in descending order.
#
# "quality" has most values concentrated in the categories 5, 6 and 7.
# Only a few observations are made for the categories 3 & 9.
#
#
# ---

# %%
df.groupby('quality').mean()   #  compute the means of each column in the groups
# Out:
#          fixed acidity  volatile acidity  ...  sulphates    alcohol
# quality                                   ...
# 3             7.600000          0.333250  ...   0.474500  10.345000
# 4             7.129448          0.381227  ...   0.476135  10.152454
# 5             6.933974          0.302011  ...   0.482203   9.808840
# 6             6.837671          0.260564  ...   0.491106  10.575372
# 7             6.734716          0.262767  ...   0.503102  11.367936
# 8             6.657143          0.277400  ...   0.486229  11.636000
# 9             7.420000          0.298000  ...   0.466000  12.180000
#
# [7 rows x 11 columns]

# %%
sns.countplot(df['quality'])   # Show the counts of observations in each categorical bin using bars
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# From the above graph we can see that most of the wines falls under quality '6', followed by '5' & '7'. There are fewer wines that are of very high quality, and very few wines that aren’t so good.
#
#
# ---

# %% [markdown]
# ## **2. Fixed acidity**
#
#
# ---

# %% [markdown]
# Fixed acidity is a measurement of the total concentration of titratable acids and free hydrogen ions present in the wine.
#
#
# ---

# %%
# checking for null values
df['fixed acidity'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(df['fixed acidity'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'fixed acidity', data = df,palette='Reds_d')

# %% [markdown]
# ## **3. Volatile acidity**
#
#
# ---

# %% [markdown]
# Volatile acidity which is mostly caused by bacteria in the wine creating acetic acid, could be an indicator of spoilage, or errors in the manufacturing processes — caused by things like damaged grapes, wine exposed to air, and so on.
#
#
# ---

# %%
# checking for null values
df['volatile acidity'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(df['volatile acidity'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'volatile acidity', data = df,palette='Greens_d')

# %% [markdown]
# ## **4. Citric acid**
#
#
# ---

# %% [markdown]
# Citric acid acts as a preservative and is added to wines to increase acidity, complement a specific flavor or prevent ferric hazes.
#
#
# ---

# %%
# checking for null values
df['citric acid'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(df['citric acid'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'citric acid', data = df,palette='RdPu_d')

# %% [markdown]
# ## **5. Residual sugar**
#
#
# ---

# %% [markdown]
# Residual Sugar refers to any natural grape sugars that are leftover after fermentation ceases.
#
#
# ---

# %%
df['residual sugar'].isnull().sum()
# Out:
# 0

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'residual sugar', data = df,palette='Blues_d')

# %% [markdown]
# ## **6. Chlorides**
#
#
# ---

# %% [markdown]
# The amount of chlorides present in a wine is usually an indicator of its “saltiness.” Too much saltiness is considered undesirable. The right proportion can make the wine more savory.
#
#
# ---

# %%
df['chlorides'].isnull().sum()
# Out:
# 0

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'chlorides', data = df,palette='Oranges_d')

# %% [markdown]
# ## **7. Free sulphur dioxide**
#
#
# ---

# %% [markdown]
# ‘Free sulphur dioxide’ is that which is unbound to compounds in the wine and is, therefore, able to exert an antioxidant/preservative action.
#
#
# ---

# %%
df['free sulfur dioxide'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(df['free sulfur dioxide'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'free sulfur dioxide', data = df,palette='terrain_d')

# %% [markdown]
# ## **8. Total sulfur dioxide**
#
#
# ---

# %% [markdown]
# Total Sulfur Dioxide (TSO2) is the portion of SO2 that is free in the wine plus the portion that is bound to other chemicals in the wine such as aldehydes, pigments, or sugars.
#
#
# ---

# %%
df['total sulfur dioxide'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(df['total sulfur dioxide'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'total sulfur dioxide', data = df,palette='Greys_d')

# %% [markdown]
# ## **9. Density**
#
#
# ---

# %% [markdown]
# Density can be used to measure the alcohol concentration in wines. Sweeter wines generally have higher densities.
#
#
# ---

# %%
df['density'].isnull().sum()
# Out:
# 0

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'density', data = df,palette='YlOrBr_d')

# %% [markdown]
# ## **10. pH**
#
#
# ---

# %% [markdown]
# pH describes how acidic or basic a wine is on a scale from 0 (very acidic) to 14 (very basic).
#
#
# ---

# %%
df['pH'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(df['pH'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'pH', data = df,palette='Purples_d')

# %% [markdown]
# ## **11. Sulphates**
#
#
# ---

# %% [markdown]
# Sulphates are salts of sulfuric acid.
#
#
# ---

# %%
df['sulphates'].isnull().sum()
# Out:
# 0

# %%
sns.countplot(df['sulphates'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'sulphates', data = df,palette='hot_d')

# %% [markdown]
# ## **12. Alcohol**
#
#
# ---

# %% [markdown]
# Alcohol measures the level of ethanol (taste) gas in wine.
#
#
# ---

# %%
df['alcohol'].isnull().sum()
# Out:
# 0

# %%
fig = plt.figure(figsize = (9,5))
sns.barplot(x = 'quality', y = 'alcohol', data = df,palette='winter_d')

# %% [markdown]
# ---
#
#
# From the above visualizations we observe that:
#
# Features fixed acidity, volatile acidity, citric acid, sulphates, density and residual sugar might not give any specification to classify/predict the quality.
#
# Quality increases with
#
# decrease in chlorides.
#
# increase in pH.
#
# increase in alcohol.
#
# Free sulfur dioxide alone will not be able to predict the quality.
#
# Total sulfur dioxide alone will not be able to predict the quality.
#
#
# ---

# %% [markdown]
# # **Data Correlation**
#
#
# ---

# %% [markdown]
# To obtain the detailed information about data correlation, correlation matrix is used. The correlation matrix gives information about how the two variables interact, both the direction and magnitude.

# %%
correlation=df.corr()
colormap=plt.cm.autumn
plt.figure(figsize=(14,10))
sns.heatmap(correlation,cmap=colormap, annot=True, linewidths=0.2)   #annot=true to display correlation

# %% [markdown]
# ---
#
#
# The correlation coefficient ranges from –1 to 1.
#
# When it is close to 1, it means that there is a strong positive correlation; for eg, strong positive correlation between the 'alcohol' and the 'quality' value.
#
# When the coefficient is close to –1, it means that there is a strong negative correlation; for eg, strong negative correlation between the ‘density’ and the ‘quality’ value.
#
# When the coefficient is close to zero, it means that there is no linear correlation.

# %% [markdown]
# free sulfur dioxide and total sulfur dioxide are highly correlated to each other with correlation of 0.62.
#
#
# ---

# %% [markdown]
# # **Binary classificaion for the target variable**

# %% [markdown]
# In this dataset there aren’t any missing values, outliers, attributes that provide no useful information for the task. So, we can conclude that this data set is clean.

# %% [markdown]
# We already know that the scores obtained for Wine are between 3 to 9. So it’s straightforward to categorize answers into ‘bad’ or ‘good’ quality of wines.This helps in visualizing the graph by finding out whether the wine is good or not.

# %% [markdown]
# As the next step, the quality of wine is divided into two buckets, ie. Good wine and Bad wine.
#
#
# ---

# %%
#Dividing the wine quality by good and bad by limits
bins=(2,6.5,9)
labels=['Bad','Good']
df['quality']=pd.cut(df['quality'],labels=labels,bins=bins)    # used to separate the array elements into different bins

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.0              0.27         0.36  ...       0.45      8.8      Bad
# 1            6.3              0.30         0.34  ...       0.49      9.5      Bad
# 2            8.1              0.28         0.40  ...       0.44     10.1      Bad
# 3            7.2              0.23         0.32  ...       0.40      9.9      Bad
# 4            7.2              0.23         0.32  ...       0.40      9.9      Bad
#
# [5 rows x 12 columns]

# %% [markdown]
# ---
#
#
#
# *   Bad wine : range 2 – 6.5
# *   Good wine : range 6.5 – 9
#
#
# This can be changed as per the requirements of the user/client.

# %% [markdown]
# The values of bad and good are mapped as 0 and 1 respectively, as machine learning models can perform calculation only on numerical data
#
#
# ---

# %%
df['quality'] = df['quality'].map({'Bad' : 0, 'Good' : 1})   # used to map values from two series having one column same
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.0              0.27         0.36  ...       0.45      8.8        0
# 1            6.3              0.30         0.34  ...       0.49      9.5        0
# 2            8.1              0.28         0.40  ...       0.44     10.1        0
# 3            7.2              0.23         0.32  ...       0.40      9.9        0
# 4            7.2              0.23         0.32  ...       0.40      9.9        0
#
# [5 rows x 12 columns]

# %% [markdown]
# From the below graph we can see that the Wines are mostly of bad quality.
#
#
# ---

# %%
sns.countplot(df['quality'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['quality'].value_counts()
# Out:
# 0    3838
# 1    1060
# Name: quality, dtype: int64

# %% [markdown]
# There are 3838 bad quality of wine and 1060 good quality of wine.
#
#
# ---

# %% [markdown]
# # **Features importance**

# %% [markdown]
# Next the feature importance of each feature of the dataset is obtained by using the feature importance property of the model. Feature importance gives a score for each feature of the data, the higher the score more important or relevant is the feature towards the output variable.
#
#
# ---

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X= df.drop("quality",axis=1)    # all featured variables 
y= df["quality"]                # only target variables
predictors = df.head(0)
selector = SelectKBest(chi2, k=10)   # k='all' or k=5 etc
sf_fit = selector.fit(X,y)  # will be used for plotting
# print features scores
for i in range(len(sf_fit.scores_)):
  print(df.columns[i],':',sf_fit.scores_[i])
# Out:
# fixed acidity : 3.3169962304932237
# volatile acidity : 0.8080591463697778
# citric acid : 0.267873049039378
# residual sugar : 270.21338519715493
# chlorides : 1.7124249123204505
# free sulfur dioxide : 21.9907792144907
# total sulfur dioxide : 1681.7771356154014
# density : 0.0035512315139639193
# pH : 0.3062335915669617
# sulphates : 0.2926719381784806
# alcohol : 104.62073253510744

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
datset=pd.DataFrame()
datset['feature']=X.columns[range(len(sf_fit.scores_))]
datset['scores']=sf_fit.scores_
datset=datset.sort_values(by='scores',ascending=False)
sns.barplot(datset['scores'],datset['feature'],color='red')
#sns.set_style('whitegrid')
plt.ylabel('Features importance',fontsize=18)
plt.xlabel('Scores',fontsize=18)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Train Test Split**

# %% [markdown]
# The dataset is then splitted into target (y) and input (X) features.

# %%
#Now seperate the dataset as response variable and feature variabes
X = df.drop('quality', axis = 1)   # dropping the 'quality' column
y = df['quality']

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4893    0
# 4894    0
# 4895    0
# 4896    1
# 4897    0
# Name: quality, Length: 4898, dtype: category
# Categories (2, int64): [0 < 1]

# %% [markdown]
# After this the data is split into training and testing data in the proportion 70:30 using sklearn train_test_split.
#
#
# ---

# %%
#Train and Test splitting of data 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42) # Here random_state=42 is used as a seed to the random number generator.

# %% [markdown]
# # **Feature Scaling / Standardization**

# %% [markdown]
# Feature Scaling or Standardization is used to normalise the data within a particular range. Standardization is about making sure that data is internally consistent; that is, each data type has the same content and format. It is a process of subtracting the means from each feature and dividing by the feature standard deviations.
#
# The ultimate goal to perform standardization  in this dataset is to bring down all the features to a common scale without distorting the differences in the range of the values.
#
#
# ---

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)    # scale the training data and also learn the scaling parameters of that data. 
X_test=sc.transform(X_test)          # the parameters learned by the model using the training data will help to transform the test data.
print(X_train)
print("##############################")
print(X_test)
# Out:
# [[-0.31132265 -0.28780076 -0.27645327 ... -1.13031916  0.0940735
#   -1.14685943]
#  [ 1.10470658 -0.18935432  1.30066456 ... -1.06354794 -1.49278025
#    0.64257527]
#  [-0.66532995 -0.48469365 -0.02743466 ...  0.87281754 -0.61119484
#    0.56123733]
#  ...
#  [ 0.86870171 -0.09090788  1.54968316 ... -1.13031916  0.35854912
#    0.72391321]
#  [-0.66532995 -0.3862472  -0.35945947 ... -0.12875081 -0.963829
#    0.07320968]
#  [ 1.45871389 -0.09090788  0.13857774 ...  0.2051053   1.24013454
#   -0.0894662 ]]
# ##############################
# [[-1.01933726  0.105985    0.63661495 ... -0.6629206   0.88750037
#    0.3714488 ]
#  [-1.72735188  2.4686996  -1.43854009 ...  0.07156286  0.35854912
#    2.18799615]
#  [ 0.27868953 -0.28780076  0.47060254 ...  0.60573264 -0.5230363
#    1.37461674]
#  ...
#  [ 0.1606871   1.18889586 -0.69148427 ... -1.26386161  0.53486621
#    0.72391321]
#  [-0.07531777  0.79511009 -0.77449048 ...  0.53896142 -1.31646317
#    1.6999685 ]
# ...

# %% [markdown]
# # **MACHINE LEARNING MODELS**

# %% [markdown]
# # **Logistic Regression**

# %% [markdown]
# Logistic regression is one of the most popular Machine Learning algorithms, which comes under the Supervised Learning technique. It is used for predicting the categorical dependent variable using a given set of independent variables.
#
#
# ---

# %% [markdown]
# First I Import the model using sklearn.linear_model and Make an instance of the Model. The model is then trained on the data. Here, model is learning the relationship between X_train and y_train. Next the model is predicted using .predict() which uses the information the model learned during the model training process.

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()    # Making an instance of the Model.
model.fit(X_train,y_train)      # learning the relationship between X_train and y_train.
y_pred = model.predict(X_test)  # prediction

# %% [markdown]
# ### *Classification Report*
#
#
# ---

# %% [markdown]
# The classification report is used to display the precision, recall, F1, and support scores for the model.
#
# Precision:- Accuracy of positive predictions.
#
# Precision = TP/(TP + FP)
#
# Recall:- Fraction of positives that were correctly identified.
#
# Recall = TP/(TP+FN)
#
# F1 score - weighted harmonic mean of precision and recall
#
# F1 Score = 2*(Recall * Precision) / (Recall + Precision)
#
# Support is the number of actual occurrences of the class in the specified dataset.

# %%
import sklearn.metrics as met
from sklearn.metrics import accuracy_score,classification_report
cr = classification_report(y_test,y_pred)   # Build a text report showing the main classification metrics.
print(cr)
accuracyscore=met.accuracy_score(y_test, y_pred)*100   # for getting the accuracy score in percentage multiply by 100
print('\n')
print('Accuracy score given for test data:',str(accuracyscore))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87      1141
#            1       0.57      0.26      0.35       329
#
#     accuracy                           0.79      1470
#    macro avg       0.69      0.60      0.61      1470
# weighted avg       0.76      0.79      0.76      1470
#
#
#
# Accuracy score given for test data: 78.9795918367347

# %% [markdown]
# Here we get the values of recall, precision, f1-score and support. The class 0 has a higher precision and recall than class 1. And the Accuracy score is coming as 78.9795918367347
#
#
# ---

# %% [markdown]
# ### *Improving model accuracy using GridSearchCV*
#
#
# ---

# %% [markdown]
# The accuracy of this model can be improved by tuning the hyperparameters of the model. To achieve this, a “grid” of parameters is defined to test out in the model and select the best model using GridSearchCV.

# %%
# Create first pipeline for base without reducing features.
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
pipe = Pipeline([('classifier' ,LogisticRegression() )])

# Create param grid.

param_grid = [
    {'classifier' : [LogisticRegression()],
     'classifier__penalty' : ['l1', 'l2'],
    'classifier__C' : np.logspace(-4, 4, 20),
    'classifier__solver' : ['liblinear']},
    
]

# Create grid search object
grid_model = GridSearchCV(pipe, param_grid = param_grid, cv = 5, verbose=True, n_jobs=-1)

# Fit on data
best_model = grid_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    4.4s finished

# %%
#Best parameters for our model
grid_model.best_params_
# Out:
# {'classifier': LogisticRegression(C=0.012742749857031334, class_weight=None, dual=False,
#                     fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                     max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
#                     random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                     warm_start=False),
#  'classifier__C': 0.012742749857031334,
#  'classifier__penalty': 'l2',
#  'classifier__solver': 'liblinear'}

# %% [markdown]
# ### *Classification Report*
#
#
# ---

# %% [markdown]
# After getting the best parameters for this model, I run the model again and obtained the classification report and accuracy score.

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(C=0.012742749857031334, class_weight=None, dual=False,
                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
                    max_iter=100, multi_class='auto', n_jobs=None, penalty='l2',
                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
                    warm_start=False)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

import sklearn.metrics as met
from sklearn.metrics import accuracy_score,classification_report
cr = classification_report(y_test,y_pred)  # Build a text report showing the main classification metrics.
print(cr)
accuracyscore=met.accuracy_score(y_test, y_pred)*100   # for getting the accuracy score in percentage multiply by 100
print('\n')
print('Accuracy score given for test data:',str(accuracyscore))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.88      1141
#            1       0.59      0.24      0.34       329
#
#     accuracy                           0.79      1470
#    macro avg       0.70      0.60      0.61      1470
# weighted avg       0.76      0.79      0.76      1470
#
#
#
# Accuracy score given for test data: 79.18367346938776

# %% [markdown]
# **Accuracy score given for test data: 79.18367346938776**

# %% [markdown]
# ### *Confusion Matrix*
#
#
# ---

# %% [markdown]
# A Confusion matrix is an N x N matrix used for evaluating the performance of a classification model, where N is the number of target classes. The matrix compares the actual target values with those predicted by the machine learning model.
#
# The target variable has two values: Positive(1) or Negative(0)
# The columns represent the actual values of the target variable
# The rows represent the predicted values of the target variable
#
# There are four ways to check if the predictions are right or wrong:
#
# TN / True Negative: the case was negative and predicted negative
#
# TP / True Positive: the case was positive and predicted positive
#
# FN / False Negative: the case was positive but predicted negative (Type 2 error)
#
# FP / False Positive: the case was negative but predicted positive (Type 1 error)

# %%
# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as pt
from sklearn.metrics import confusion_matrix
conmat=confusion_matrix(y_test,y_pred)   # Compute confusion matrix to evaluate the accuracy of a classification.
sns.heatmap(conmat.T, square=True, annot=True, fmt='d', cbar=False,cmap='Blues_r') # square=True, set the Axes aspect to “equal” so each cell will be square-shaped.    # annot=True write the data value in each cell.  # cbar=False means Whether to draw a colorbar.
pt.xlabel('Actual class') 
pt.ylabel('Predicted class')
# Out:
# Text(91.68, 0.5, 'Predicted class')

# %% [markdown]
# ### *roc_curve*
#
#
# ---

# %% [markdown]
# An ROC curve (receiver operating characteristic curve) is a graph showing the performance of a classification model at all classification thresholds. This curve plots two parameters: True Positive Rate. False Positive Rate.

# %%
from sklearn.metrics import roc_auc_score,roc_curve
fpr,tpr, thresholds =roc_curve(y_test,model.predict_proba(X_test)[:,1])

# %%
model_roc_auc=roc_auc_score(y_test,model.predict_proba(X_test)[:,1])
model_roc_auc
# Out:
# 0.7756673743769795

# %% [markdown]
# False Positive Rates and True Postive rates for the Classifier are obtained because these will be used to plot the ROC Curve. This can be done by roc_curve module by passing the test dataset and the predicted data through it.

# %% [markdown]
# ROC curve has False Positive Rate (FPR) on the X-axis and True Positive Rate (TPR) on the Y-axis.
#
#
# ---

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(fpr,tpr,label='Logistic regression'%model_roc_auc)
plt.plot([0,1],[0,1],'r--')    # red color in dashed
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# The area covered by the curve is the area between the blue line (ROC) and the axis. This area covered is AUC. The bigger the area covered, the better this machine learning model is at distinguishing the given classes.
#
#
# ---

# %% [markdown]
# # **GaussianNB**

# %% [markdown]
# Naive Bayes is a supervised machine learning classification algorithms based on the Bayes theorem. Gaussian Naive Bayes is a variant of Naive Bayes that follows Gaussian normal distribution and supports continuous data. Gaussian NB is used because it is the easier to work with as it only needs to estimate the mean and the standard deviation from the training data.
#
#
# ---

# %% [markdown]
# First I Import the model using sklearn.naive_bayes and Make an instance of the Model. The model is then trained on the data. Here, model is learning the relationship X_train and y_train. Next the model is predicted using .predict() which uses the information the model learned during the model training process.

# %%
from sklearn.naive_bayes import GaussianNB
model1 = GaussianNB()     # Making an instance of the Model.
model1.fit(X_train,y_train)    # learning the relationship between X_train and y_train.
y_pred1 = model1.predict(X_test)   # prediction

# %% [markdown]
# ### *Confusion Matrix*
#
#
# ---

# %%
# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as pt
from sklearn.metrics import confusion_matrix
conmat=confusion_matrix(y_test,y_pred1)   # Compute confusion matrix to evaluate the accuracy of a classification.
sns.heatmap(conmat.T, square=True, annot=True, fmt='d', cbar=False,cmap='Reds_r') # square=True, set the Axes aspect to “equal” so each cell will be square-shaped.    # annot=True write the data value in each cell.  # cbar=False means Whether to draw a colorbar.
pt.xlabel('Actual class') 
pt.ylabel('Predicted class')
# Out:
# Text(91.68, 0.5, 'Predicted class')

# %% [markdown]
# ### *Classification Report*
#
#
# ---

# %%
import sklearn.metrics as met
from sklearn.metrics import accuracy_score,classification_report
cr = classification_report(y_test,y_pred1)  # Build a text report showing the main classification metrics.
print(cr)
accuracyscore=met.accuracy_score(y_test, y_pred1)*100   # for getting the accuracy score in percentage multiply by 100
print('\n')
print('Accuracy score given for test data:',str(accuracyscore))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.71      0.79      1141
#            1       0.41      0.68      0.51       329
#
#     accuracy                           0.71      1470
#    macro avg       0.65      0.70      0.65      1470
# weighted avg       0.78      0.71      0.73      1470
#
#
#
# Accuracy score given for test data: 70.54421768707483

# %% [markdown]
# Here we get the values of recall, precision, f1-score and support.
#
# **Accuracy score given for test data: 70.54421768707483**
#
#
# ---

# %% [markdown]
# ### *roc_curve*
#
#
# ---

# %%
from sklearn.metrics import roc_auc_score,roc_curve
fpr,tpr,thresholds=roc_curve(y_test,model1.predict_proba(X_test)[:,1])
model1_roc_auc=roc_auc_score(y_test,model1.predict_proba(X_test)[:,1])

import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(fpr,tpr,label='Gaussian NB'%model1_roc_auc)
plt.plot([0,1],[0,1],'r--')    # red color in dashed
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # **K Neighbors Classifier**

# %% [markdown]
# K Neighbors Classifier  assumes the similarity between the new case/data and available cases and put the new case into the category that is most similar to the available categories.
#
#
# ---

# %% [markdown]
# First I Import the model using sklearn.neighbors and Make an instance of the Model. The model is then trained on the data. Here, model is learning the relationship X_train and y_train. Next the model is predicted using .predict() which uses the information the model learned during the model training process.

# %%
from sklearn.neighbors import KNeighborsClassifier
model2 = KNeighborsClassifier(n_neighbors=3)     # Making an instance of the Model.
model2.fit(X_train,y_train)    # learning the relationship between X_train and y_train.
y_pred2 = model2.predict(X_test)   # prediction

# %% [markdown]
# ### *Confusion Matrix*
#
#
# ---

# %%
# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as pt
from sklearn.metrics import confusion_matrix
conmat=confusion_matrix(y_test,y_pred2) # Compute confusion matrix to evaluate the accuracy of a classification.
sns.heatmap(conmat.T, square=True, annot=True, fmt='d', cbar=False,cmap='Greens_r') # square=True, set the Axes aspect to “equal” so each cell will be square-shaped.    # annot=True write the data value in each cell.  # cbar=False means Whether to draw a colorbar.
pt.xlabel('Actual class') 
pt.ylabel('Predicted class')
# Out:
# Text(91.68, 0.5, 'Predicted class')

# %% [markdown]
# ### *Classification Report*
#
#
# ---

# %%
import sklearn.metrics as met
from sklearn.metrics import accuracy_score,classification_report
cr = classification_report(y_test,y_pred2)   # Build a text report showing the main classification metrics.
print(cr)
accuracyscore=met.accuracy_score(y_test, y_pred2)*100    # for getting the accuracy score in percentage multiply by 100
print('\n')
print('Accuracy score given for test data:',str(accuracyscore))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89      1141
#            1       0.65      0.55      0.59       329
#
#     accuracy                           0.83      1470
#    macro avg       0.76      0.73      0.74      1470
# weighted avg       0.82      0.83      0.83      1470
#
#
#
# Accuracy score given for test data: 83.26530612244898

# %% [markdown]
# Here we get the values of recall, precision, f1-score and support.
#
# **Accuracy score given for test data: 83.26530612244898**
#
#
# ---

# %% [markdown]
# ### *roc_curve*
#
#
# ---

# %%
from sklearn.metrics import roc_auc_score,roc_curve
fpr,tpr,thresholds=roc_curve(y_test,model2.predict_proba(X_test)[:,1])
model2_roc_auc=roc_auc_score(y_test,model2.predict_proba(X_test)[:,1])

import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(fpr,tpr,label='K Neighbors classifier'%model2_roc_auc)
plt.plot([0,1],[0,1],'r--')    # red color in dashed
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # **Decision Tree**

# %% [markdown]
# Decision Tree is a Supervised Machine learning technique that can be used for both classification and Regression problems, but mostly it is preferred for solving Classification problems. It is a tree-structured classifier, where internal nodes represent the features of a dataset, branches represent the decision rules and each leaf node represents the outcome.
#
#
# ---

# %% [markdown]
# First I Import the model using sklearn.tree and Make an instance of the Model. The model is then trained on the data. Here, model is learning the relationship X_train and y_train. Next the model is predicted using .predict() which uses the information the model learned during the model training process.

# %%
from sklearn.tree import DecisionTreeClassifier
model3 = DecisionTreeClassifier(criterion='entropy',random_state=7)     
model3.fit(X_train,y_train)    # learning the relationship between X_train and y_train.
y_pred3 = model3.predict(X_test)   # prediction

# %% [markdown]
# ### *Confusion Matrix*
#
#
# ---

# %%
# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as pt
from sklearn.metrics import confusion_matrix
conmat=confusion_matrix(y_test,y_pred3) # Compute confusion matrix to evaluate the accuracy of a classification.
sns.heatmap(conmat.T, square=True, annot=True, fmt='d', cbar=False,cmap='autumn') # square=True, set the Axes aspect to “equal” so each cell will be square-shaped.    # annot=True write the data value in each cell.  # cbar=False means Whether to draw a colorbar.
pt.xlabel('Actual class') 
pt.ylabel('Predicted class')
# Out:
# Text(91.68, 0.5, 'Predicted class')

# %% [markdown]
# ### *Classification Report*
#
#
# ---

# %%
import sklearn.metrics as met
from sklearn.metrics import accuracy_score,classification_report
cr = classification_report(y_test,y_pred3)    # Build a text report showing the main classification metrics.
print(cr)
accuracyscore=met.accuracy_score(y_test, y_pred3)*100   # for getting the accuracy score in percentage multiply by 100
print('\n')
print('Accuracy score given for test data:',str(accuracyscore))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89      1141
#            1       0.62      0.65      0.63       329
#
#     accuracy                           0.83      1470
#    macro avg       0.76      0.77      0.76      1470
# weighted avg       0.84      0.83      0.83      1470
#
#
#
# Accuracy score given for test data: 83.33333333333334

# %% [markdown]
# Here we get the values of recall, precision, f1-score and support.
#
# **Accuracy score given for test data: 83.33333333333334**
#
#
# ---

# %% [markdown]
# ### *roc_curve*
#
#
# ---

# %%
from sklearn.metrics import roc_auc_score,roc_curve
fpr,tpr,thresholds=roc_curve(y_test,model3.predict_proba(X_test)[:,1])
model3_roc_auc=roc_auc_score(y_test,model3.predict_proba(X_test)[:,1])

import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(fpr,tpr,label='Decision Tree'%model3_roc_auc)
plt.plot([0,1],[0,1],'r--')    # red color in dashed
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # **Random Forest**

# %% [markdown]
# Random Forest is based on the concept of ensemble learning, which is a process of combining multiple classifiers to solve a complex problem and to improve the performance of the model. Instead of relying on one decision tree, the random forest takes the prediction from each tree and based on the majority votes of predictions, and it predicts the final output.
# The greater number of trees in the forest leads to higher accuracy and prevents the problem of overfitting.
#
#
# ---

# %% [markdown]
# First I Import the model using sklearn.ensemble and Make an instance of the Model. The model is then trained on the data. Here, model is learning the relationship X_train and y_train. Next the model is predicted using .predict() which uses the information the model learned during the model training process.

# %%
from sklearn.ensemble import RandomForestClassifier
model4 = RandomForestClassifier(random_state=1)
model4.fit(X_train, y_train)     # learning the relationship between X_train and y_train.
y_pred4 = model4.predict(X_test)    # prediction

# %% [markdown]
# ### *Confusion Matrix*
#
#
# ---

# %%
# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as pt
from sklearn.metrics import confusion_matrix
conmat=confusion_matrix(y_test,y_pred4) # Compute confusion matrix to evaluate the accuracy of a classification.
sns.heatmap(conmat.T, square=True, annot=True, fmt='d', cbar=False,cmap='Oranges_r') # square=True, set the Axes aspect to “equal” so each cell will be square-shaped.    # annot=True write the data value in each cell.  # cbar=False means Whether to draw a colorbar.
pt.xlabel('Actual class') 
pt.ylabel('Predicted class')
# Out:
# Text(91.68, 0.5, 'Predicted class')

# %% [markdown]
# ### *Classification Report*
#
#
# ---

# %%
import sklearn.metrics as met
from sklearn.metrics import accuracy_score,classification_report
cr = classification_report(y_test,y_pred4)   # Build a text report showing the main classification metrics.
print(cr)
accuracyscore=met.accuracy_score(y_test, y_pred4)*100    # for getting the accuracy score in percentage multiply by 100
print('\n')
print('Accuracy score given for test data:',str(accuracyscore))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92      1141
#            1       0.82      0.58      0.68       329
#
#     accuracy                           0.88      1470
#    macro avg       0.86      0.77      0.80      1470
# weighted avg       0.87      0.88      0.87      1470
#
#
#
# Accuracy score given for test data: 87.82312925170068

# %% [markdown]
# Here we get the values of recall, precision, f1-score and support.
#
# **Accuracy score given for test data: 87.82312925170068**
#
#
# ---

# %% [markdown]
# ### *roc_curve*
#
#
# ---

# %%
from sklearn.metrics import roc_auc_score,roc_curve
fpr,tpr,thresholds=roc_curve(y_test,model4.predict_proba(X_test)[:,1])
model4_roc_auc=roc_auc_score(y_test,model4.predict_proba(X_test)[:,1])

import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(fpr,tpr,label='Random Forest'%model4_roc_auc)
plt.plot([0,1],[0,1],'r--')    # red color in dashed
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # **SVC**

# %% [markdown]
# SVC is a nonparametric clustering algorithm that does not make any assumption on the number or shape of the clusters in the data
#
#
# ---

# %% [markdown]
# First I Import the model using sklearn.svm and Make an instance of the Model. The model is then trained on the data. Here, model is learning the relationship X_train and y_train. Next the model is predicted using .predict() which uses the information the model learned during the model training process.

# %%
from sklearn.svm import SVC
model5 = SVC()    # Making an instance of the Model.
model5.fit(X_train,y_train)     # learning the relationship between X_train and y_train.
y_pred5 = model5.predict(X_test)    # prediction

# %% [markdown]
# ### *Classification Report*
#
#
# ---

# %%
import sklearn.metrics as met
from sklearn.metrics import accuracy_score,classification_report
cr = classification_report(y_test,y_pred5)    # Build a text report showing the main classification metrics.
print(cr)
accuracyscore=met.accuracy_score(y_test, y_pred5)*100    # for getting the accuracy score in percentage multiply by 100
print('\n')
print('Accuracy score given for test data:',str(accuracyscore))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      1141
#            1       0.74      0.33      0.45       329
#
#     accuracy                           0.82      1470
#    macro avg       0.79      0.65      0.67      1470
# weighted avg       0.81      0.82      0.80      1470
#
#
#
# Accuracy score given for test data: 82.31292517006803

# %% [markdown]
# ### *Improving model accuracy using GridSearchCV*
#
#
# ---

# %%
# Create first pipeline for base without reducing features.
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
pipe = Pipeline([('classifier' ,SVC() )])

# Create param grid.

param_grid = [
    {'classifier' : [SVC()],
     'classifier__C' : [0.1,0.8,0.9,1,1.1,1.2,1.3,1.4],
    'classifier__kernel' : ['linear', 'rbf'],
    'classifier__gamma' : [0.1,0.8,0.9,1,1.1,1.2,1.3,1.4]},
    
]

# Create grid search object
grid_model5 = GridSearchCV(pipe, param_grid = param_grid, cv = 10, verbose=True, n_jobs=-1)

# Fit on data
best_model5 = grid_model5.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 128 candidates, totalling 1280 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 388 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 888 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 1280 out of 1280 | elapsed:  3.7min finished

# %%
grid_model5.best_params_
# Out:
# {'classifier': SVC(C=1.4, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#      decision_function_shape='ovr', degree=3, gamma=1.3, kernel='rbf',
#      max_iter=-1, probability=False, random_state=None, shrinking=True,
#      tol=0.001, verbose=False),
#  'classifier__C': 1.4,
#  'classifier__gamma': 1.3,
#  'classifier__kernel': 'rbf'}

# %% [markdown]
# ### *Classification Report*
#
#
# ---

# %%
from sklearn.svm import SVC
model5 = SVC(C=1.4, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
     decision_function_shape='ovr', degree=3, gamma=1.3, kernel='rbf',
     max_iter=-1, probability=True, random_state=None, shrinking=True,
     tol=0.001, verbose=False)
model5.fit(X_train,y_train)
y_pred5 = model5.predict(X_test)

import sklearn.metrics as met
from sklearn.metrics import accuracy_score,classification_report
cr = classification_report(y_test,y_pred5)   # Build a text report showing the main classification metrics.
print(cr)
accuracyscore=met.accuracy_score(y_test, y_pred5)*100   # for getting the accuracy score in percentage multiply by 100
print('\n')
print('Accuracy score given for test data:',str(accuracyscore))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1141
#            1       0.85      0.50      0.63       329
#
#     accuracy                           0.87      1470
#    macro avg       0.86      0.74      0.77      1470
# weighted avg       0.87      0.87      0.85      1470
#
#
#
# Accuracy score given for test data: 86.80272108843538

# %% [markdown]
# Here we get the values of recall, precision, f1-score and support. The class 0 has a higher precision and recall than class 1.
#
# **Accuracy score given for test data: 86.80272108843538**
#
#
# ---

# %% [markdown]
# ### *Confusion Matrix*
#
#
# ---

# %%
# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as pt
from sklearn.metrics import confusion_matrix
conmat=confusion_matrix(y_test,y_pred5)    # Compute confusion matrix to evaluate the accuracy of a classification.
sns.heatmap(conmat.T, square=True, annot=True, fmt='d', cbar=False)  # square=True, set the Axes aspect to “equal” so each cell will be square-shaped.    # annot=True write the data value in each cell.  # cbar=False means Whether to draw a colorbar.
pt.xlabel('Actual class') 
pt.ylabel('Predicted class')
# Out:
# Text(91.68, 0.5, 'Predicted class')

# %% [markdown]
# ## *roc_curve*
#
#
# ---

# %%
from sklearn.metrics import roc_auc_score,roc_curve
fpr,tpr,thresholds=roc_curve(y_test,model5.predict_proba(X_test)[:,1])
model5_roc_auc=roc_auc_score(y_test,model5.predict_proba(X_test)[:,1])

import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(fpr,tpr,label='Random Forest'%model5_roc_auc)
plt.plot([0,1],[0,1],'r--')    # red color in dashed
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # **MODEL ACCURACY**

# %%
results = pd.DataFrame({
    'Models': ['Logistic Regression','GaussianNB', 'K Neighbors','Decision Tree' ,'Random Forest','SVC'],
    'Scores': [0.79,0.71,0.83,0.83,0.88,0.87]})         
result_df = results.sort_values(by='Scores', ascending=False)   # sorts the data frame in descending order of Scores.
result_df = result_df.set_index('Scores')   # set a Scores as index of a Data Frame.
result_df
# Out:
#                      Models
# Scores
# 0.88          Random Forest
# 0.87                    SVC
# 0.83            K Neighbors
# 0.83          Decision Tree
# 0.79    Logistic Regression
# 0.71             GaussianNB

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# To detect the quality of white wine accurately and efficiently, different Machine learning models has been proposed- Random Forest, SVC,  KNeighbors, Decision Tree, Logistic Regression and GaussianNB. The results obtained in the above table show that the Random Forest and SVC has a high capability to detect the quality of wine. The proposed models achieved 88% and 87% accuracies which is high compared with the other models. Thus, the results suggest that the Random Forest and SVC models are more reliable for accurate detection of White wine quality.

# %% [markdown]
# # **Wine Quality App for Prediction**

# %% [markdown]
# ### *The pycharm code for the website is in the .py file*
#
# ### *The below pictures are the screenshots of that website*

# %% [markdown]
# ![Cap.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Capture1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Capture2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Capture3.PNG](data:image/png;base64,...)

# %% [markdown]
# ## From the above screenshots of the website we can see that after putting the float values of all the 11 feature variables, the quality value is coming as " 7 " which is clearly a good quality of Wine.

# %% [markdown]
# # **THE END!!!**

# %% [markdown]
# # **THANK YOU**
